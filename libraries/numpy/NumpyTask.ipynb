# %% [markdown]
# # Numpy Task

# %% [markdown]
# ### Instructions:
# - Answer the following questions using NumPy only.
# - Do not use Python loops unless explicitly stated.

# %% [markdown]
# ## Part 1: Creating Arrays (3 Questions)

# %% [markdown]
# ####  1) Create a NumPy array that contains all even numbers between 10 and 50 (inclusive).

# %%
import numpy as np
earray = np.arrange(10,51,2)
print (earray)

# %% [markdown]
# #### 2) Create an array of shape (3, 4) filled with ones, then change all values in the last column to 0.

# %%
array = np.ones((3,4))
array[ :-1]=0

# %% [markdown]
# #### 3) Create a NumPy array of 5 equally spaced numbers between -1 and 1.

# %%
result = np.linspace(-1,1,5)

# %% [markdown]
# ## Part 2: Array Properties (3 Questions)

# %% [markdown]
# #### 1) Create array and then
# - Find its shape
#
# - Number of elements
#
# - Data type

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(f"Shape: {arr.shape}")
print(f"Size: {arr.size}")
print(f"Data Type: {arr.dtype}")

# %% [markdown]
# #### 2) Create a random array of size 10 and find:
# - minimum value
#
# - maximum value
#
# - standard deviation

# %%
random_arr = np.random.rand(10)
print(f"Array: {random_arr}")
print(f"Maximum value: {random_arr.max()}")
print(f"Minimum value: {random_arr.min()}")
print(f"Sum of elements: {random_arr.sum()}")
print(f"Mean: {random_arr.mean()}")

# %% [markdown]
# #### 3) What is the difference between arr.size and arr.shape?
#
# - Explain using an example.

# %%
arr shape بتوضح عدد الصفوف و الاعمدة يعني بتدينا رقمين
arr size بتدينا رقمواحد وهو رقم العناصر كلها اللي موجودة في المصفوفة

# %% [markdown]
# ## Part 3: Mathematical Operations & ufuncs (3 Questions)

# %% [markdown]
# #### 1) Create a new array that contains the square of each element without using loops.

# %%
# Given 

arr = np.array([1, 2, 3, 4, 5])

# %% [markdown]
# #### 2) Compute the mean and sum of all values in a 3×3 random matrix.

# %%
mat=np.random.rand(3,3)
summ=np.sum(mat)
meann=np.mean(mat)

# %% [markdown]
# #### 3) Compute the mean and sum of all values in a 3×3 random matrix.

# %% [markdown]
# ## Part 4: Indexing, Slicing & Boolean Indexing (4 Questions)

# %% [markdown]
# #### 1) Extract the middle four elements using slicing.

# %%
# Given 
arr = np.array([10, 20, 30, 40, 50, 60])
melements=arr[1:5]

# %% [markdown]
# #### 2) From the same array, extract all values greater than 25.

# %%
greater25=arr[arr>25]

# %% [markdown]
# #### 3) Modify the array so that all values less than 30 become 0.

# %%
arr[arr<30]=0

# %% [markdown]
# #### 4) When would slicing be better than Boolean indexing?
# Give one example.

# %%
slicing بيكون احسن لما نكون عارفبن مواقع العناصر وعايزين مثلا جزء منتظم منها يعني لما ما بنكنش محتاجين نفحص القيم نفسها

# %% [markdown]
# ## Part 5: Random Numbers & Performance (3 Questions)

# %% [markdown]
# #### 1) Generate a reproducible array of 15 random integers between 1 and 100.

# %%
np.ramdom.seed(42)
rr_arr=np.random.radiant(1,101,15)

# %% [markdown]
# #### 2) Create two arrays:
#
# - one using a Python loop
#
# - one using NumPy vectorization
#
# ``to add 10 to each element.``
#
# **Which one is faster and why?**

# %%
arr_loop = np.arange(1000)
result_loop = [x + 10 for x in arr_loop]

# %%
arr_np = np.arange(1000)
result_np = arr_np + 10

# %% [markdown]
# #### 4) Why is `np.random.seed()` important in data science experiments?

# %% [markdown]
# بتخلي الارقام العشوائية اللي ظهرت في اول مرة لتشغيل الكود هي اللي تظهر في كل الكود يشغل فيها نفس الارقام يعني

# %% [markdown]
# ## Part 6: Linear Algebra & Matrix Operations (2 Questions)

# %% [markdown]
# #### 1) Compute the determinant and inverse of a square matrix of your choice.

# %%
matrix = np.array([[1, 2], [3, 4]])
det = np.linalg.det(matrix)
inv = np.linalg.inv(matrix)

# %% [markdown]
# #### 2) What is the difference between:
#
# - element-wise multiplication
#
# - matrix multiplication
# in NumPy?

# %% [markdown]
# element wise multiplication بتضرب كل العنصر في العنصر اللي قصاده في النصفوفة
# matrix multiplication بيضرب صف في عمود

# %% [markdown]
# ## Bonus (Optional – Mindset Question)

# %% [markdown]
# #### How does NumPy help a Data Analyst think in a vectorized and mathematical way instead of a procedural one?

# %% [markdown]
# numpy بيخلينا بدل ما نعدي على عنصر عنصر زي ال loop
# لا هي بيتخلينا نعمل عملية رياضية على المجموعة كلها مرة واحده وده بيساعد محلل البيانات عشان كدا العملية اسرع و الكود اخف
